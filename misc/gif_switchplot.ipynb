# %%
import os
from PIL import Image, ImageDraw, ImageFont

def create_gif_frame(image_dir, filename, font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf'):
    """
    Creates a single image frame (with title) to be used for GIF generation.
    """
    im_path = os.path.join(image_dir, filename)
    im = Image.open(im_path)

    # Add title 
    font = ImageFont.truetype(font_path, size=20)  
    draw = ImageDraw.Draw(im)
    text_w, text_h = draw.textsize(filename, font=font)
    draw.text(((im.width - text_w) / 2, 10), filename, font=font, fill='black') # Black font color for visibility 

    return im

def create_gif_from_images(image_dir, output_path, duration=0.5, font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf'):
    """
    Creates a GIF from images in a directory.
    """
    filenames = sorted(os.listdir(image_dir), key=lambda x: int(x.split('_')[1].split('.')[0]))
    images = []
    for filename in filenames:
        images.append(create_gif_frame(image_dir, filename, font_path))

    images[0].save('debug_frame.png')  # Save the first frame for debugging
    images[0].save(output_path, save_all=True, append_images=images[1:], duration=duration*1000, loop=0)


def create_gifs_from_subdirectories(base_dir, output_dir, duration=0.1, font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf'):
    """ 
    Creates GIFs from images within each subdirectory, saving them directly to the output directory.
    """
    for subdir in os.listdir(base_dir):
        subdir_path = f"{base_dir}/{subdir}/ppg"
        if os.path.isdir(subdir_path):
            gif_name = subdir + ".gif" 
            output_path = os.path.join(output_dir, gif_name)  # Output directly to output_dir
            create_gif_from_images(subdir_path, output_path, duration, font_path)

# Example usage
base_dir = "plot"  # Replace with your base directory
output_dir = "gif"  # Replace with your desired output directory
create_gifs_from_subdirectories(base_dir, output_dir)

# %%
import glob

run_id = "w414p1jl"
image_root_dir = glob.glob(f'/user/hc3295/queue-learning/wandb/*{run_id}/files/media/images')[0]
image_dirs = glob.glob(f'{image_root_dir}/*.png')

# %%
from PIL import Image, ImageDraw, ImageFont
import re

def extract_number(filename):
    """
    Extracts the number from the filename using regex.
    """
    match = re.search(r'switch_plot_(\d+)', filename)
    return int(match.group(1)) if match else 0

def add_title_to_image(image_path, title_text, font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', font_size=30):
    """
    Adds a title to an image.
    """
    image = Image.open(image_path)
    draw = ImageDraw.Draw(image)
    font = ImageFont.truetype(font_path, font_size)
    textwidth, textheight = draw.textbbox((0, 0), title_text, font=font)[2:]
    
    # Calculate the x,y coordinates of the text
    margin = 10
    x = (image.width - textwidth) // 2
    y = margin
    
    # Draw the text on the image
    draw.text((x, y), title_text, font=font, fill=(0, 0, 0))
    return image

def create_gif_from_sorted_images(image_paths, output_path, duration=0.05, font_path='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf'):
    """
    Creates a GIF from sorted images, adding a title to each frame.
    """
    images = []
    for image_path in image_paths:
        title_text = f"Number: {extract_number(image_path)}"
        image = add_title_to_image(image_path, title_text, font_path)
        images.append(image)
    
    images[0].save(output_path, save_all=True, append_images=images[1:], duration=duration*1000, loop=0)

# Sort image_dirs by the number in their filename
sorted_image_dirs = sorted(image_dirs, key=extract_number)

# Create a gif from the sorted images
create_gif_from_sorted_images(sorted_image_dirs, f'sweep_gifs/n_model_{run_id}.gif')

# %%
image_dirs
# Out:
# ['/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_89_4896097f8c92403c51ca.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_98_e0208a464cac693c89b2.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_75_7c4e55152db98742e011.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_67_e2554368b7212e255f3f.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_69_5ed9ed18a3fa4cefe61d.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_7_69dd5a8aae8e3d280937.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_46_8c0d6139abc2f4dc9603.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_99_4a00c26d01c05418aea3.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_37_a276477dda6825b9ac9f.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_44_b09f07f6adcc3e76cf07.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_39_9b163d4fbf343f47c98d.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_77_b1582285b1e1fe0d72d8.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_2_e67feb46ae2a766547a9.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_15_26c54578ee69d9aa7293.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_10_243e36c155892181cd05.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_100_e773bdfa92b34330e0bc.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_23_dec33e096fe0e5b770a3.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_96_c175813d742ec5785ab0.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_25_2bb787dd5ef8bf428089.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_27_2ab37c7a872c71b23e9b.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_21_6b2032e266eeb34e8a01.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_81_0c09cf4d8568ff1aa86a.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_38_51b04bf1f58d94f89ccb.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_101_a8b4c4effe63800754b1.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_80_e4e64972a5f4aedd832f.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_57_f671506ca097011413e3.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_59_20631cf59f5d34e4fe9c.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_16_0c1cefdcc9df60c97228.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_11_71831a2558ad003611a6.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_3_bf476d5368104150b875.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_32_3e2d4472ba682ada57ff.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_82_64ae731a6e5708b06b7e.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_47_2f6132b9cf21d8f04e10.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_4_a268fb32973ca4d457f1.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_65_a009c03cdddb705aa079.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_95_8d0975bf3dd8104c1821.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_70_9a59f68693905749ddde.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_31_6832a4b7852d813cc710.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_40_278e9b8b08c9ff17d8ff.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_62_64995ce58bc53ea12fd8.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_14_d46c5936e40195e47b89.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_91_fc1af2d0ec1947585c44.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_61_a8811470740287a8fe9a.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_35_e07605c5bc566f73e79c.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_60_a576db93ca29aa138297.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_88_e0844ed23f1c797ab2ae.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_63_43a9a4a7253bc48de6e4.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_5_412410c141db49f70465.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_55_9711ea76000f7f9132e3.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_18_7281c8e32b3eccf9ce03.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_41_ffe87d3539d903c4b58c.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_50_bbe19eeb2cd08cb2e63c.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_85_380ac4a643077100a2ab.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_84_b69857fc6ebd944a804e.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_22_2436cc1f14c0ae0cea18.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_56_7e41bbd0e29b49425013.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_48_810c41486d7e5055c437.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_103_91d23f8ccab10515eadf.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_79_9c838e87ec2428103c49.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_29_084f04b4851a3d6b91b8.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_71_fbab766a3cbf04950d98.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_1_106760ea1d5185b6e4e8.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_36_075151d297da8cc25609.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_90_30fad586afe53416ac86.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_43_79cad512c9ea432b1837.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_54_db948e6ae455e45430eb.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_28_e4ee0ca46c0ae2e576ba.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_74_1f7fb044339eafc48112.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_73_2fdac8c76dfc71697ca2.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_49_54787f76b7c2ff2770f1.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_34_9af474bbe4ead2175e9d.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_53_bb5534c6af302911a7b4.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_24_c70b4ea789e787ea058e.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_6_9d82dfe6cbd060f9e210.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_76_0eb9532ed49251aa3636.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_8_f18be3ee928dc3824216.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_51_fd7a88e933fd758c9968.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_12_c49aa1a02bcece3dcb44.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_19_67be30ad92e1073c35f4.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_30_ce927123d18fb6b2a6ba.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_13_e56135f2065f2f5c8b8c.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_9_8375607bcf9acde525ba.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_45_f5ff5b6276f2134e3d62.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_92_80b8ac7cf84fa8f54a32.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_42_ba0889e8bcc5bf66341d.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_94_4d3cfe90c88795378c68.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_102_af3f555ca5b573800ba5.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_83_533d57d03047fccff311.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_72_965d79971c0363901856.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_66_8c866014e21922e91f99.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_86_8f3272cc2f8e0f73e3c6.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_64_4ecd2c4f4b8c94e0eb18.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_20_03dc74c2bdac34f71759.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_93_83dcb5066c797295e954.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_97_1f97a20ccc6441128429.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_17_c7136d26451d7308e034.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_87_7e93e91088a2edc4d070.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_33_800057f92aacbbfbf26f.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_68_f1e08b9bb4dd1df9e856.png',
#  '/user/hc3295/queue-learning/wandb/run-20240404_030323-s7ur0spb/files/media/images/switch_plot_58_f022ac3a2276bd3ed6e6.png']

# %%
# !mkdir sweep_gifs
